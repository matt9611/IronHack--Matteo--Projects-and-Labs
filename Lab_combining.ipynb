# %%
import pandas as pd
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv'
df = pd.read_csv(url)
url1 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv'
df1 = pd.read_csv(url1)
url2 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv'
df2 = pd.read_csv(url2)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4008 entries, 0 to 4007
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer                   1071 non-null   object
#  1   ST                         1071 non-null   object
#  2   GENDER                     954 non-null    object
#  3   Education                  1071 non-null   object
#  4   Customer Lifetime Value    1068 non-null   object
#  5   Income                     1071 non-null   float64
#  6   Monthly Premium Auto       1071 non-null   float64
#  7   Number of Open Complaints  1071 non-null   object
#  8   Policy Type                1071 non-null   object
#  9   Vehicle Class              1071 non-null   object
#  10  Total Claim Amount         1071 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 344.6+ KB
# None

# %%
df.shape
# Out:
# (4008, 11)

# %%
df.head
# Out:
# <bound method NDFrame.head of      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df1.head
# Out:
# <bound method NDFrame.head of     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
# ...

# %%
df2.head
# Out:
# <bound method NDFrame.head of     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
# ...

# %%
df_c= pd.concat([df, df1,df2], axis=0)

# %%
df_c.shape
# Out:
# (6000, 11)

# %%
df_c = df_c.drop_duplicates()

# %%
df_c.shape
# Out:
# (2065, 11)

# %%
df_c.info
# Out:
# <bound method DataFrame.info of     Customer          ST GENDER             Education Customer Lifetime Value  \
# 0    RB50392  Washington    NaN                Master                     NaN
# 1    QZ44356     Arizona      F              Bachelor              697953.59%
# 2    AI49188      Nevada      F              Bachelor             1288743.17%
# 3    WW63253  California      M              Bachelor              764586.18%
# 4    GA49547  Washington      M  High School or Below              536307.65%
# ..       ...         ...    ...                   ...                     ...
# 991  HV85198     Arizona      M                Master              847141.75%
# 992  BS91566     Arizona      F               College              543121.91%
# 993  IL40123      Nevada      F               College              568964.41%
# 994  MY32149  California      F                Master              368672.38%
# 995  SA91515  California      M              Bachelor              399258.39%
#
# ...

# %%
df_c.describe()
# Out:
#              Income  Monthly Premium Auto  Total Claim Amount
# count   2064.000000           2064.000000         2064.000000
# mean   39506.675872            169.289729          410.833935
# std    30338.414847           1219.971732          283.192990
# min        0.000000             61.000000            0.382107
# 25%    15162.750000             68.000000          245.354739
# 50%    36509.000000             81.000000          350.400000
# 75%    64289.500000            108.000000          523.815839
# max    99981.000000          35354.000000         2893.239678

# %%
df_c.isnull().sum()
# Out:
# Customer                       1
# ST                             1
# GENDER                       123
# Education                      1
# Customer Lifetime Value        8
# Income                         1
# Monthly Premium Auto           1
# Number of Open Complaints      1
# Policy Type                    1
# Vehicle Class                  1
# Total Claim Amount             1
# dtype: int64

# %%
df_c.GENDER.unique()
# Out:
# array([nan, 'F', 'M', 'Femal', 'Male', 'female'], dtype=object)

# %%
df_c['GENDER']=df_c['GENDER'].replace({'Male':'M', 'Femal':'F', 'female':'F' })

# %%
df_c.GENDER.unique()
# Out:
# array([nan, 'F', 'M'], dtype=object)

# %%
df_c.isnull().sum()
# Out:
# Customer                       1
# ST                             1
# GENDER                       123
# Education                      1
# Customer Lifetime Value        8
# Income                         1
# Monthly Premium Auto           1
# Number of Open Complaints      1
# Policy Type                    1
# Vehicle Class                  1
# Total Claim Amount             1
# dtype: int64

# %%
gender_mode = df_c['GENDER'].mode()[0]

# Fill null values in the GENDER column with the mode
df_c['GENDER'] = df_c['GENDER'].fillna(gender_mode)

# %%
df_c.isnull().sum()
# Out:
# Customer                     1
# ST                           1
# GENDER                       0
# Education                    1
# Customer Lifetime Value      8
# Income                       1
# Monthly Premium Auto         1
# Number of Open Complaints    1
# Policy Type                  1
# Vehicle Class                1
# Total Claim Amount           1
# dtype: int64

# %%
df_c= df_c.dropna()

# %%
df_c.isnull().sum()
# Out:
# Customer                     0
# ST                           0
# GENDER                       0
# Education                    0
# Customer Lifetime Value      0
# Income                       0
# Monthly Premium Auto         0
# Number of Open Complaints    0
# Policy Type                  0
# Vehicle Class                0
# Total Claim Amount           0
# dtype: int64

# %%
url3 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv'
mkt = pd.read_csv(url3)

# %%
mkt.shape
# Out:
# (10910, 27)

# %%
mkt.head()
# Out:
#    unnamed:_0 customer       state  customer_lifetime_value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective_to_date employmentstatus gender  ...  \
# 0     Basic   College        2011-02-18         Employed      M  ...
# 1     Basic   College        2011-01-18       Unemployed      F  ...
# 2     Basic  Bachelor        2011-02-10         Employed      M  ...
# 3  Extended   College        2011-01-11         Employed      M  ...
# 4   Premium  Bachelor        2011-01-17    Medical Leave      F  ...
#
#    number_of_policies     policy_type        policy  renew_offer_type  \
# ...

# %%
df_c.columns = df_c.columns.str.lower()

# %%
df_c.shape
# Out:
# (2057, 11)

# %%
df_c.columns = df_c.columns.str.replace(' ', '_')

# %%
df_c.head()
# Out:
#   customer          st gender             education customer_lifetime_value  \
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
# 5  OC83172      Oregon      F              Bachelor              825629.78%
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
# 5  62902.0                  69.0                    1/0/00   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
mkt.head()
# Out:
#    unnamed:_0 customer       state  customer_lifetime_value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective_to_date employmentstatus gender  ...  \
# 0     Basic   College        2011-02-18         Employed      M  ...
# 1     Basic   College        2011-01-18       Unemployed      F  ...
# 2     Basic  Bachelor        2011-02-10         Employed      M  ...
# 3  Extended   College        2011-01-11         Employed      M  ...
# 4   Premium  Bachelor        2011-01-17    Medical Leave      F  ...
#
#    number_of_policies     policy_type        policy  renew_offer_type  \
# ...

# %%
df_c.rename(columns={'st': 'state'}, inplace=True)

# %%
df_c.head()
# Out:
#   customer       state gender             education customer_lifetime_value  \
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
# 5  OC83172      Oregon      F              Bachelor              825629.78%
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
# 5  62902.0                  69.0                    1/0/00   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
mkt.isnull().sum()
# Out:
# unnamed:_0                       0
# customer                         0
# state                            0
# customer_lifetime_value          0
# response                         0
# coverage                         0
# education                        0
# effective_to_date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location_code                    0
# marital_status                   0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# policy_type                      0
# policy                           0
# renew_offer_type                 0
# sales_channel                    0
# total_claim_amount               0
# vehicle_class                    0
# vehicle_size                     0
# vehicle_type                     0
# month                            0
# ...

# %%
mkt.tail()
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928       No
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# 10905   Premium  Bachelor        2011-01-19       Unemployed      F  ...
# 10906     Basic   College        2011-01-06         Employed      F  ...
# 10907  Extended  Bachelor        2011-02-06         Employed      F  ...
# 10908   Premium   College        2011-02-13         Employed      F  ...
# 10909     Basic  Bachelor        2011-01-08       Unemployed      M  ...
#
#        number_of_policies     policy_type        policy  renew_offer_type  \
# ...

# %%
mkt.gender.unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
pivot_mkt = mkt.pivot_table( columns='sales_channel', values=['total_claim_amount'], aggfunc='sum').round(2)

# %%
pivot_mkt
# Out:
# sales_channel            Agent     Branch  Call Center        Web
# total_claim_amount  1810226.82  1301204.0    926600.82  706600.04

# %%
pivot_mkt = mkt.pivot_table( columns='education', values=['customer_lifetime_value'], aggfunc='sum')

# %%
pivot_mkt
# Out:
# education                    Bachelor       College        Doctor  \
# customer_lifetime_value  2.549632e+07  2.531183e+07  2.956184e+06
#
# education                High School or Below        Master
# customer_lifetime_value          2.647451e+07  7.240159e+06
